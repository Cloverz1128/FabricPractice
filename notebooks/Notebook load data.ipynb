# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# Out:
# StatementMeta(, 4a38c6dc-e7c4-4335-be61-ac1bdf87f2d6, 3, Finished, Available, Finished)

# %%
df = spark.read.format("csv").option("header","true").load("Files/MtoMActual.csv")
# df now is a Spark DataFrame containing CSV data from "Files/MtoMActual.csv".
display(df)
# Out:
# StatementMeta(, 4a38c6dc-e7c4-4335-be61-ac1bdf87f2d6, 4, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, b307cd48-ee59-4ad4-bae3-b8f8ccbbc691)

# %%
df = spark.read.csv("Files/MtoMActual.csv")
# df now is a Spark DataFrame containing CSV data from "Files/MtoMActual.csv".
display(df)
# Out:
# StatementMeta(, 4a38c6dc-e7c4-4335-be61-ac1bdf87f2d6, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 97ef48aa-fe51-459f-8e7e-38b5d9061568)

# %%
df = spark.read.load("Files/MtoMActual.csv", format='csv', header=True)
# df now is a Spark DataFrame containing CSV data from "Files/MtoMActual.csv".
display(df)
# Out:
# StatementMeta(, 4a38c6dc-e7c4-4335-be61-ac1bdf87f2d6, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 0c2059b1-169e-4789-a95e-eb8c305003f5)

# %% [markdown]
# ABFS Path: abfss://MyWorkspace@onelake.dfs.fabric.microsoft.com/mylakehouse.Lakehouse/Files/MtoMActual.csv
#
# workspace: MyWorkspace@onelake.dfs.fabric.microsoft.com/
#
# lakehouse: mylakehouse.Lakehouse
#
# Relative Path: Files/MtoMActual.csv
#
# This path can be used in different lakehouse

# %%
import pandas as pd
# Load data into pandas DataFrame from "/lakehouse/default/Files/MtoMActual.csv"
df = pd.read_csv("/lakehouse/default/Files/MtoMActual.csv")
display(df)
# Out:
# StatementMeta(, 4a38c6dc-e7c4-4335-be61-ac1bdf87f2d6, 8, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 6d94cce8-efe6-4808-a7f2-4f5ae5573b3c)

# %% [markdown]
# File API Path: /lakehouse/default/Files/MtoMActual.csv
#
# using for pandas
